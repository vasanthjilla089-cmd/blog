# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthjilla089-cmd/blog/blob/main/Aduldonates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project title  Aduld

# %% [markdown]
# ### stage -1

# %% [markdown]
#  # Problem Statement
#
# To predict whether an individual's annual income is greater than $50K or less than or equal to $50K using demographic and employment-related information from the Adult Census Income dataset.

# %% [markdown]
#  **STAGE-1**
# *italicised text*

# %% [markdown]
# ### Source-  UCI Machine Learning Repository (Adult Census Income Dataset)
# ### Timeline-  2020
# ### Location- tamil nadu

# %% [markdown]
# ##Type of Problem
#
# Binary Classification
#
#  ## Regression/Classification
#
# Classification
#
# ## Dataset Features Description
# Age – Age of the individual
# Workclass – Employment type
# Education – Highest education level
# Education-num – Numerical education level
# Marital-status – Marital status
# Occupation – Job type
# Relationship – Family relationship
# Race – Race of the individual
# Sex – Gender
# Capital-gain – Capital gain
# Capital-loss – Capital loss
# Hours-per-week – Weekly working hours
# Native-country – Country of origin
# Income (Target) – >50K or <=50K

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import zipfile

# Define the column names based on the dataset description
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status',
                'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss',
                'hours-per-week', 'native-country', 'income']

# Path to the zip file
zip_file_path = '/content/adult.zip'
# Name of the data file inside the zip
data_file_name = 'adult.data'

# Extract the data file from the zip archive
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extract(data_file_name, '/content/') # Extract to /content/

# Load the dataset, specifying no header and assigning custom column names
df = pd.read_csv(f'/content/{data_file_name}', header=None, names=column_names)

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
print(df.columns[:1])

# %% [markdown]
# ### Shape

# %%
df.shape

# %% [markdown]
# ### Describing the dataset

# %% [markdown]
# The Adult Census Income dataset contains 48,842 records and 14 input features with 1 target variable (Income). It includes demographic and employment-related information such as age, education, occupation, workclass, marital status, hours per week, and native country. The objective is to predict whether an individual's annual income is greater than $50K or less than or equal to $50K. The dataset contains both numerical and categorical features, with a few missing values.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Finding the duplicates
#
# Project Result:
#
# Input: Person demographic and employment details
# ⬇️
# Machine Learning Model (Logistic Regression)
# ⬇️
# Output: Income Category (<=50K or >50K)

# %%
df.duplicated

# %% [markdown]
# ## Target** Feature
# Income (>50K or <=50K)
# Input Features
# Age
# Workclass
# Fnlwgt
# Education
# Education-num
# Marital-status
# Occupation
# Relationship
# Race
# Sex
# Capital-gain
# Capital-loss
# Hours-per-week
# Native-country

# %% [markdown]
# ## stage -2

# %% [markdown]
# ### Information about the dataset
#
# Information about the Dataset
# Dataset Name: Adult Census Income Dataset
# Total Records: 48,842
# Input Features: 14

# %% [markdown]
# # This is formatted as code
# ###  Handling missing values

# %%
df.isnull().sum()

# %% [markdown]
# ### univariate analysis

# %%
df['income'].value_counts()

# %% [markdown]
# # This is formatted as code
# ###  Handling missing values

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
X = df[['age',
        'workclass',
        'fnlwgt',
        'education',
        'education-num',
        'marital-status',
        'occupation',
        'relationship',
        'race',
        'sex',
        'capital-gain',
        'capital-loss',
        'hours-per-week',
        'native-country']]

y = df['income']

# %%
X = df.drop('income', axis=1)
y = df['income']

# %%
le = LabelEncoder()

y = le.fit_transform(y)

# %%
import matplotlib.pyplot as plt

# Boxplots for all numerical columns
df.boxplot(figsize=(15, 6), rot=90)
plt.title("Boxplot for Numerical Features")
plt.show()

# Detect Outliers Using IQR Method
# Select numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Detect outliers
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(f"{col}: {len(outliers)} outliers")

# %% [markdown]
# ### Bi-variate Analysis

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='income',
    y='age',
    data=df
)

plt.title('Income vs. Age Distribution')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='income', data=df)

plt.title("Income Distribution")
plt.xlabel("Income Category")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['age'], bins=20)

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['education'].value_counts().plot(kind='bar')

plt.title('Education Level')
plt.xlabel('Education')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['hours-per-week'], bins=20)

plt.title('Hours per Week')
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['age'], df['hours-per-week'])

plt.title("Age vs Hours per Week")
plt.xlabel("Age")
plt.ylabel("Hours per Week")
plt.show()

# %%
plt.figure(figsize=(10,5))
df['workclass'].value_counts().plot(kind='bar')

plt.title("Workclass Distribution")
plt.xlabel("Workclass")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# ## **Stage 3**

# %% [markdown]
# ### Feature Selection and Model Building (using multiple models)

# %%
X = df.drop('income', axis=1)
y = df['income']

# %%
le = LabelEncoder()

y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# Identify categorical columns in X
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns

# Apply One-Hot Encoding to categorical features
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# Encode the target variable y
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Split the encoded data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_encoded, test_size=0.2, random_state=42
)

# Scale numerical features (important for Logistic Regression convergence)
scaler = StandardScaler()
X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])


# Create model
model = LogisticRegression(max_iter=1000) # Increased max_iter for convergence

# Train model
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Confusion Matrix
print(confusion_matrix(y_test, y_pred))

# Classification Report
print(classification_report(y_test, y_pred))

# %%
m = model.coef_[0]
c = model.intercept_[0]

# %%
print(model.coef_)
print(model.intercept_)

# %%
y_pred = model.predict(X_test)

print(y_pred)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

print(y_pred)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)

# %%
confusion_matrix(y_test, y_pred)

# %%
print(classification_report(y_test,y_pred))

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    class_weight="balanced",
    max_iter=1000
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np

# Ensure the model is fitted before using it
model.fit(X_train, y_train)

z = model.decision_function(X_test)

y_sigmoid = 1 / (1 + np.exp(-z))

y_sigmoid[:5]

# %%
y_sigmoid = 0.75

if y_sigmoid >= 0.5:
    print("Income >50K")

elif y_sigmoid < 0.5:
    print("Income <=50K")

else:
    print("Invalid")

# %%
new_data = X_test.iloc[0:5]

# %%
y_pred = model.predict(new_data)

y_pred

# %%
X.columns

# %%
y_prob = model.predict_proba(new_data)

y_prob

# %%
y_sigmoid = model.predict_proba(new_data)[:,1]

y_sigmoid

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

cm

# %% [markdown]
# ### Model Evaluation and Comparison

# %% [markdown]
# Accuracy
# Precision
# Confusion Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Blues")

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# அடுத்தது ROC Curve + AUC Score பார்க்கலாம்.

# %% [markdown]
# stage - 4

# %% [markdown]
# # Project Documentation

# %% [markdown]
# Project Title
# Adult Income Classification using Machine Learning (Logistic Regression)

# %% [markdown]
# Process Overview
# 1. Data Collection
# Adult Income (Census Income) dataset was collected.
# The dataset contains demographic and employment-related information of individuals.
# The target variable is Income (<=50K or >50K).
# 2. Data Understanding
# Checked dataset structure using:
# head()
# shape
# info()
# describe()
# Identified:
# Numerical features
# Categorical features
# Target variable
